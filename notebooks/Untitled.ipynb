# %%
import __init__

# %%
from datatools import Data
from config import LOCS
import numpy as np

# %%
X_train = np.load(LOCS.X_train)

# %%
X_train.shape
# Out:
# (5331, 30, 64, 64)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.imshow(X_train[2][1])

# %%
y_train = np.load(LOCS.y_train)

# %%
y_train[0:30]
# Out:
# array([[ 108.3,  246.7],
#        [ 108.3,  246.7],
#        [ 108.3,  246.7],
#        [ 108.3,  246.7],
#        [ 108.3,  246.7],
#        [ 108.3,  246.7],
#        [ 108.3,  246.7],
#        [ 108.3,  246.7],
#        [ 108.3,  246.7],
#        [ 108.3,  246.7],
#        [ 108.3,  246.7],
#        [ 108.3,  246.7],
#        [ 108.3,  246.7],
#        [ 108.3,  246.7],
#        [ 108.3,  246.7],
#        [ 108.3,  246.7],
#        [ 105.2,  219.3],
#        [ 105.2,  219.3],
#        [ 105.2,  219.3],
#        [ 105.2,  219.3],
#        [ 105.2,  219.3],
#        [ 105.2,  219.3],
#        [ 105.2,  219.3],
#        [ 105.2,  219.3],
#        [ 105.2,  219.3],
#        [ 105.2,  219.3],
#        [ 121.3,  283.6],
#        [ 121.3,  283.6],
#        [ 121.3,  283.6],
#        [ 121.3,  283.6]])
