# %%
import __init__

# %%
import matplotlib.pyplot as plt

from skimage.restoration import denoise_tv_chambolle

from datatools import Data
from config import LOCS

# %matplotlib inline
from matplotlib import rcParams

# %%
train = Data(LOCS.train_dir)

# %%
labels = {}

# %%
patient = 1

# %%
sax_slices = [sl for sl in train.samples[patient].keys() if 'sax' in sl]
sax_slices.sort(key=lambda x:int(x.split('_')[1]))

# %%
for sl in sax_slices:
    print sl
    fig = plt.figure()
    images = train.samples[patient][sl]
    for i,im in enumerate([1,10,20,30]):
        fig.add_subplot(2,2,i+1)
        plt.imshow(images[im].pixels)
    plt.subplots_adjust(wspace=0.01,hspace=0.01)
    plt.show()
# Out:
# sax_5
# sax_6
# sax_7
# sax_8
# sax_9
# sax_10
# sax_11
# sax_12
# sax_13
# sax_14
# sax_15
# sax_16
# sax_17
# sax_18
# sax_38
# sax_57
